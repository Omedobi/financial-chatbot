# %% [markdown]
# # Testing the chatbot prototype logic

# %%
#load the module/libraries
import pandas as pd
import seaborn as sns
import os, sys

sys.path.append('../src/chatbot_prototype')

# %%
#load the dataset

df1 = pd.read_json(r"..\dataset\Final_report\10k_final_report.json")

df2 = pd.read_json(r'..\dataset\Final_report\10k_summary_report.json')

# %%
print(df1.info())
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Year                                 15 non-null     int64
#  1   Total_revenue                        15 non-null     float64
#  2   Net_income                           15 non-null     float64
#  3   Total_assets                         15 non-null     float64
#  4   Total_liabilities                    15 non-null     float64
#  5   Cash_flow_from_operating_activities  15 non-null     int64
#  6   Company                              15 non-null     object
#  7   Revenue_growth_(%)                   15 non-null     float64
#  8   Net_income_growth_(%)                15 non-null     float64
#  9   Assets_growth_(%)                    15 non-null     float64
#  10  Liabilities_growth_(%)               15 non-null     float64
# ...

# %%
print(df2.info())

df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Company                              3 non-null      object
#  1   Revenue_growth_(%)                   3 non-null      float64
#  2   Net_income_growth_(%)                3 non-null      float64
#  3   Assets_growth_(%)                    3 non-null      float64
#  4   Liabilities_growth_(%)               3 non-null      float64
#  5   Cash_flow_from_operating_growth_(%)  3 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 168.0+ bytes
# None
#      Company  Revenue_growth_(%)  Net_income_growth_(%)  Assets_growth_(%)  \
# 0      Apple           -8.353242             -10.608322          -3.706486
# 1  Microsoft          -12.120416             -15.157741         -11.241376
# ...

# %%
# %run "D://Jobs//BCG GenAI//src//chatbot_prototype//chatbot_logic.py"
# Out:
# The Cash flow from operation activities for Apple for fiscal year 2024 is $ 118254
#
# You can ask questions like:
# - What is the total revenue?
# - What is the net income?
# - What is the profit margin?
# - What is the debt-to-assets ratio?
# - Which company had the highest revenue?
# - what is the revenue growth %?
# - what is the cash flow from operation activities?
# - what is the sum of the total liabilities?
# - what is the sum of the total assets?
# - what is the sum of the total assets?
# - which company had the highest net income?
# - Summarize the financial performance
# Enter 'back' to select a different company or fiscal year.
# The Cash flow from operation activities for Apple for fiscal year 2024 is $ 118254
#
# You can ask questions like:
# - What is the total revenue?
# - What is the net income?
# - What is the profit margin?
# - What is the debt-to-assets ratio?
# - Which company had the highest revenue?
# - what is the revenue growth %?
# ...
